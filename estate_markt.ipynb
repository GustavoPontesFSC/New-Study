# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import download_housing as dowhou

# %%
dowhou.fetch_housing_data()

# %%
A = dowhou.loud_housing().array()

# %%
print(A)
# Out:
#             0      1     2       3       4       5       6       7         8  \
# 0     -122.23  37.88  41.0   880.0   129.0   322.0   126.0  8.3252  452600.0
# 1     -122.22  37.86  21.0  7099.0  1106.0  2401.0  1138.0  8.3014  358500.0
# 2     -122.24  37.85  52.0  1467.0   190.0   496.0   177.0  7.2574  352100.0
# 3     -122.25  37.85  52.0  1274.0   235.0   558.0   219.0  5.6431  341300.0
# 4     -122.25  37.85  52.0  1627.0   280.0   565.0   259.0  3.8462  342200.0
# ...       ...    ...   ...     ...     ...     ...     ...     ...       ...
# 20635 -121.09  39.48  25.0  1665.0   374.0   845.0   330.0  1.5603   78100.0
# 20636 -121.21  39.49  18.0   697.0   150.0   356.0   114.0  2.5568   77100.0
# 20637 -121.22  39.43  17.0  2254.0   485.0  1007.0   433.0  1.7000   92300.0
# 20638 -121.32  39.43  18.0  1860.0   409.0   741.0   349.0  1.8672   84700.0
# 20639 -121.24  39.37  16.0  2785.0   616.0  1387.0   530.0  2.3886   89400.0
#
#               9
# 0      NEAR BAY
# ...

# %%
x = A[:,0]
y = A[:,1]
print(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Portifólio/Mercado Imobiliário/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Documents/Portifólio/Mercado Imobiliário/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/Portifólio/Mercado Imobiliário/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
np.amax(A[:,8])
# Out:
# 500001.0

# %%
value = 500000
v = A[:,8] > value
v_2 = A[:,8] <= value

# %%
plt.plot(x[v_2], y[v_2],'b*')
plt.plot(x[v], y[v],'r*')
plt.show()
