# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import download_housing as dowhou

# %%
dowhou.fetch_housing_data()

# %%
a = dowhou.loud_housing()

# %%
a.csv_path.head()
# Out:
#            0         1                   2            3               4  \
# 0  longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 1    -122.23     37.88                41.0        880.0           129.0
# 2    -122.22     37.86                21.0       7099.0          1106.0
# 3    -122.24     37.85                52.0       1467.0           190.0
# 4    -122.25     37.85                52.0       1274.0           235.0
#
#             5           6              7                   8                9
# 0  population  households  median_income  median_house_value  ocean_proximity
# 1       322.0       126.0         8.3252            452600.0         NEAR BAY
# 2      2401.0      1138.0         8.3014            358500.0         NEAR BAY
# 3       496.0       177.0         7.2574            352100.0         NEAR BAY
# 4       558.0       219.0         5.6431            341300.0         NEAR BAY

# %%
A = a.array()

# %%
x = A[:,0]
y = A[:,1]
print(x, y)
# Out:
# [-122.23 -122.22 -122.24 ... -121.22 -121.32 -121.24] [37.88 37.86 37.85 ... 39.43 39.43 39.37]

# %%
Unique = np.unique(A[:,9])
HV = A[:,8] > 490000
Unique
# Out:
# array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#       dtype=object)

# %%
for i in Unique:
    plt.plot(x[A[:,9] == i] , y[A[:,9] == i] , '*', label = i)    
plt.plot(x[HV], y[HV], '*' ,color = 'deeppink', label = 'Value > U$490,000.00')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend()
plt.grid()
plt.show()

# %%
housing = a.csv_path

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20641 non-null  object
#  1   1       20641 non-null  object
#  2   2       20641 non-null  object
#  3   3       20641 non-null  object
#  4   4       20434 non-null  object
#  5   5       20641 non-null  object
#  6   6       20641 non-null  object
#  7   7       20641 non-null  object
#  8   8       20641 non-null  object
#  9   9       20641 non-null  object
# dtypes: object(10)
# memory usage: 1.6+ MB

# %%
housing['ocean_proximity'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Portifólio/NEW/NEW-STUDY/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Documents/Portifólio/NEW/NEW-STUDY/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/Portifólio/NEW/NEW-STUDY/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'ocean_proximity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
housing.describe()

# %%
housing.hist(bins=50, figsize=(20,15), color= 'red')
plt.show()
